# %%
import time
import os
import random
import math
import torch
import torch.autograd
import torch.nn.functional as F
from torch.autograd import Variable
from bisect import bisect_left
import matplotlib.pyplot as plt


#Functions for dataset Generation
#################################

def generate_dataset(N):
    dataset = [exponential() for _ in range(N)]
    #dataset = [lognormal() for _ in range(N)]
    #dataset = [laplace() for _ in range(N)]
    #dataset = [uniform() for _ in range(N)]
    #dataset = [gaussian() for _ in range(N)]
    dataset = sorted(dataset)
    def KVrand():
        x = random.choice(dataset)
        y = dataset.index(x)
        return x, y
    return dataset, KVrand

def exponential(lambda1=1.0):
    u = random.random()
    x = - math.log(u) / lambda1
    return x 

def lognormal(mu=0, sigma=5.0):
    x = random.lognormvariate(mu, sigma)
    return x
  
def uniform(a=0.0,b=10.0):
    x = random.uniform(a,b)
    return x

def gaussian(mu=0, sigma=5.0):
    x = random.gauss(mu, sigma)
    return x

def laplace():
    u = random.random()
    if(u<=0.5):
        x = math.log(2*u)
    else:
        x = -math.log(2-2*u)    
    return x


#Functions for Neural Network Configuration
###########################################

def create_NN(dim=128):
    NN = torch.nn.Sequential(torch.nn.Linear(1, dim),torch.nn.ReLU(),torch.nn.Linear(dim, 1),)
    return NN


def to_tensor(x):   
    return torch.unsqueeze(Variable(torch.Tensor(x)), 1)


#Traditional Search Functions
#############################

def linear_search(x, dataset):
    for idx, n in enumerate(dataset):
        if n > x:
            break
    return idx - 1


def binary_search(x, dataset):
    i = bisect_left(dataset, x)
    if i:
        return i - 1
    raise ValueError

#Main
#####

def main():
    N = 1000
    lr = 0.001
    batch_no = 0
    LF_x = []
    LF_y = []  
    minloss = N
    
    
    dataset, KVrand = generate_dataset(N)
    NN = create_NN()
    optimizer = torch.optim.Adam(NN.parameters(), lr=lr)
    
#Training
#########

    start = time.time()
    try:
        while True:
            batch_no = batch_no + 1
            batch_x = []; batch_y = []
            for _ in range(256):
                x, y = KVrand()
                batch_x.append(x)
                batch_y.append(y)

            batch_x = to_tensor(batch_x)
            batch_y = to_tensor(batch_y)

            Predicted_idx = NN(batch_x) * N

            output = F.smooth_l1_loss(Predicted_idx, batch_y)
            loss = output.data
                      
            if (minloss>loss.item()):
               minloss=loss.item()
               #print('Minloss =',minloss,'at',time.time())

            #print(loss, minloss,'at',time.time())  
            
            LF_x.append(batch_no)
            LF_y.append(loss)
            
            if (loss.item()<1.0):
                break
            
            optimizer.zero_grad()
            output.backward()
            optimizer.step()
    except KeyboardInterrupt:
        pass
    end = time.time()
    TrainingTime = end - start
    print('Time required for Training =', TrainingTime)

#Testing
########

    def test(x):
        start = time.time()
        Predicted_idx = NN(to_tensor([x])) * N
        end = time.time()
        tp = end - start
        start = time.time()
        idx1 = binary_search(x, dataset)
        end = time.time()
        tb = end - start
        start = time.time()
        idx2 = linear_search(x, dataset)
        end = time.time()
        ti = end - start
        print('for x=', x,'BSearch:', idx1, 'IdxSearch:', idx2, 'Predicted:', float(Predicted_idx.data[0]))
        return ti,tb,tp

    timeI=0
    timeB=0
    timeP=0
    TF_x = []
    TF_y1 = []
    TF_y2 = []
    TF_y3 = []
    for x in range(10,110):
        #ti,tb,tp = test(random.choice(dataset))
        ti,tb,tp = test(float(x/100))
        timeI=timeI+ti
        timeB=timeB+tb
        timeP=timeP+tp
        TF_x.append(x)

    print('Time required for Linear Search:', timeI)
    print('Time required for Binary Search:', timeB)
    print('Time required for Learned Index:', timeP)

if __name__ == '__main__':
    main()
# Out:
# Time required for Training = 11.748270511627197
# for x= 0.1 BSearch: 70 IdxSearch: 70 Predicted: 72.05615997314453
# for x= 0.11 BSearch: 83 IdxSearch: 83 Predicted: 82.56587219238281
# for x= 0.12 BSearch: 94 IdxSearch: 94 Predicted: 92.96826934814453
# for x= 0.13 BSearch: 103 IdxSearch: 103 Predicted: 103.00798797607422
# for x= 0.14 BSearch: 112 IdxSearch: 112 Predicted: 113.04772186279297
# for x= 0.15 BSearch: 123 IdxSearch: 123 Predicted: 121.27979278564453
# for x= 0.16 BSearch: 130 IdxSearch: 130 Predicted: 128.90306091308594
# for x= 0.17 BSearch: 137 IdxSearch: 137 Predicted: 136.5264129638672
# for x= 0.18 BSearch: 146 IdxSearch: 146 Predicted: 144.1497344970703
# for x= 0.19 BSearch: 151 IdxSearch: 151 Predicted: 151.7730255126953
# for x= 0.2 BSearch: 158 IdxSearch: 158 Predicted: 159.3963165283203
# for x= 0.21 BSearch: 166 IdxSearch: 166 Predicted: 167.01962280273438
# for x= 0.22 BSearch: 169 IdxSearch: 169 Predicted: 174.64292907714844
# for x= 0.23 BSearch: 175 IdxSearch: 175 Predicted: 182.26622009277344
# for x= 0.24 BSearch: 183 IdxSearch: 183 Predicted: 190.5507049560547
# for x= 0.25 BSearch: 195 IdxSearch: 195 Predicted: 198.8436737060547
# for x= 0.26 BSearch: 208 IdxSearch: 208 Predicted: 207.13670349121094
# for x= 0.27 BSearch: 219 IdxSearch: 219 Predicted: 215.42970275878906
# for x= 0.28 BSearch: 228 IdxSearch: 228 Predicted: 223.72268676757812
# for x= 0.29 BSearch: 234 IdxSearch: 234 Predicted: 232.00502014160156
# for x= 0.3 BSearch: 240 IdxSearch: 240 Predicted: 238.64874267578125
# for x= 0.31 BSearch: 244 IdxSearch: 244 Predicted: 244.9940948486328
# for x= 0.32 BSearch: 250 IdxSearch: 250 Predicted: 251.3394012451172
# for x= 0.33 BSearch: 256 IdxSearch: 256 Predicted: 257.68475341796875
# for x= 0.34 BSearch: 263 IdxSearch: 263 Predicted: 264.0300598144531
# for x= 0.35 BSearch: 271 IdxSearch: 271 Predicted: 270.3558044433594
# for x= 0.36 BSearch: 279 IdxSearch: 279 Predicted: 276.48614501953125
# for x= 0.37 BSearch: 282 IdxSearch: 282 Predicted: 282.61651611328125
# for x= 0.38 BSearch: 287 IdxSearch: 287 Predicted: 288.7468566894531
# for x= 0.39 BSearch: 293 IdxSearch: 293 Predicted: 294.87725830078125
# for x= 0.4 BSearch: 301 IdxSearch: 301 Predicted: 301.4034423828125
# for x= 0.41 BSearch: 308 IdxSearch: 308 Predicted: 307.9798278808594
# for x= 0.42 BSearch: 316 IdxSearch: 316 Predicted: 314.55615234375
# for x= 0.43 BSearch: 320 IdxSearch: 320 Predicted: 321.1325378417969
# for x= 0.44 BSearch: 326 IdxSearch: 326 Predicted: 327.76239013671875
# for x= 0.45 BSearch: 332 IdxSearch: 332 Predicted: 334.42913818359375
# for x= 0.46 BSearch: 341 IdxSearch: 341 Predicted: 341.09588623046875
# for x= 0.47 BSearch: 348 IdxSearch: 348 Predicted: 347.7626037597656
# for x= 0.48 BSearch: 353 IdxSearch: 353 Predicted: 354.4293212890625
# for x= 0.49 BSearch: 363 IdxSearch: 363 Predicted: 361.0960998535156
# for x= 0.5 BSearch: 366 IdxSearch: 366 Predicted: 367.7628479003906
# for x= 0.51 BSearch: 377 IdxSearch: 377 Predicted: 374.42962646484375
# for x= 0.52 BSearch: 387 IdxSearch: 387 Predicted: 381.0963134765625
# for x= 0.53 BSearch: 391 IdxSearch: 391 Predicted: 387.734375
# for x= 0.54 BSearch: 396 IdxSearch: 396 Predicted: 394.1236572265625
# for x= 0.55 BSearch: 400 IdxSearch: 400 Predicted: 400.5125427246094
# for x= 0.56 BSearch: 406 IdxSearch: 406 Predicted: 406.8828125
# for x= 0.57 BSearch: 410 IdxSearch: 410 Predicted: 413.25311279296875
# for x= 0.58 BSearch: 416 IdxSearch: 416 Predicted: 419.62335205078125
# for x= 0.59 BSearch: 430 IdxSearch: 430 Predicted: 425.9936218261719
# for x= 0.6 BSearch: 438 IdxSearch: 438 Predicted: 432.364013671875
# for x= 0.61 BSearch: 440 IdxSearch: 440 Predicted: 438.73431396484375
# for x= 0.62 BSearch: 446 IdxSearch: 446 Predicted: 445.1046142578125
# for x= 0.63 BSearch: 454 IdxSearch: 454 Predicted: 451.47491455078125
# for x= 0.64 BSearch: 457 IdxSearch: 457 Predicted: 457.8451232910156
# for x= 0.65 BSearch: 463 IdxSearch: 463 Predicted: 464.2154846191406
# for x= 0.66 BSearch: 469 IdxSearch: 469 Predicted: 470.5858459472656
# for x= 0.67 BSearch: 475 IdxSearch: 475 Predicted: 476.9560852050781
# for x= 0.68 BSearch: 483 IdxSearch: 483 Predicted: 483.41558837890625
# for x= 0.69 BSearch: 492 IdxSearch: 492 Predicted: 489.9264221191406
# for x= 0.7 BSearch: 495 IdxSearch: 495 Predicted: 496.4372253417969
# for x= 0.71 BSearch: 506 IdxSearch: 506 Predicted: 502.2587890625
# for x= 0.72 BSearch: 508 IdxSearch: 508 Predicted: 507.6054382324219
# for x= 0.73 BSearch: 512 IdxSearch: 512 Predicted: 512.9520874023438
# for x= 0.74 BSearch: 517 IdxSearch: 517 Predicted: 518.2987670898438
# for x= 0.75 BSearch: 522 IdxSearch: 522 Predicted: 523.6453857421875
# for x= 0.76 BSearch: 528 IdxSearch: 528 Predicted: 528.9920043945312
# for x= 0.77 BSearch: 535 IdxSearch: 535 Predicted: 534.3386840820312
# for x= 0.78 BSearch: 538 IdxSearch: 538 Predicted: 539.36474609375
# for x= 0.79 BSearch: 544 IdxSearch: 544 Predicted: 544.1093139648438
# for x= 0.8 BSearch: 548 IdxSearch: 548 Predicted: 548.2162475585938
# for x= 0.81 BSearch: 551 IdxSearch: 551 Predicted: 552.3231811523438
# for x= 0.82 BSearch: 557 IdxSearch: 557 Predicted: 556.43017578125
# for x= 0.83 BSearch: 560 IdxSearch: 560 Predicted: 560.5370483398438
# for x= 0.84 BSearch: 566 IdxSearch: 566 Predicted: 564.64404296875
# for x= 0.85 BSearch: 569 IdxSearch: 569 Predicted: 568.7509765625
# for x= 0.86 BSearch: 573 IdxSearch: 573 Predicted: 572.8579711914062
# for x= 0.87 BSearch: 576 IdxSearch: 576 Predicted: 576.96484375
# for x= 0.88 BSearch: 578 IdxSearch: 578 Predicted: 581.0718383789062
# for x= 0.89 BSearch: 584 IdxSearch: 584 Predicted: 585.1787719726562
# for x= 0.9 BSearch: 591 IdxSearch: 591 Predicted: 589.2857055664062
# for x= 0.91 BSearch: 593 IdxSearch: 593 Predicted: 593.3927001953125
# for x= 0.92 BSearch: 597 IdxSearch: 597 Predicted: 597.4996337890625
# for x= 0.93 BSearch: 602 IdxSearch: 602 Predicted: 601.6066284179688
# for x= 0.94 BSearch: 607 IdxSearch: 607 Predicted: 605.7135620117188
# for x= 0.95 BSearch: 611 IdxSearch: 611 Predicted: 609.583740234375
# for x= 0.96 BSearch: 614 IdxSearch: 614 Predicted: 612.8118896484375
# for x= 0.97 BSearch: 614 IdxSearch: 614 Predicted: 616.0502319335938
# for x= 0.98 BSearch: 618 IdxSearch: 618 Predicted: 619.3093872070312
# for x= 0.99 BSearch: 621 IdxSearch: 621 Predicted: 622.6809692382812
# for x= 1.0 BSearch: 621 IdxSearch: 621 Predicted: 626.0526733398438
# for x= 1.01 BSearch: 625 IdxSearch: 625 Predicted: 629.42431640625
# for x= 1.02 BSearch: 631 IdxSearch: 631 Predicted: 632.7960815429688
# for x= 1.03 BSearch: 639 IdxSearch: 639 Predicted: 636.1676635742188
# for x= 1.04 BSearch: 641 IdxSearch: 641 Predicted: 639.5393676757812
# for x= 1.05 BSearch: 644 IdxSearch: 644 Predicted: 642.9109497070312
# for x= 1.06 BSearch: 645 IdxSearch: 645 Predicted: 646.2826538085938
# for x= 1.07 BSearch: 652 IdxSearch: 652 Predicted: 649.6468505859375
# for x= 1.08 BSearch: 655 IdxSearch: 655 Predicted: 652.981201171875
# for x= 1.09 BSearch: 656 IdxSearch: 656 Predicted: 656.1549072265625
# Time required for Linear Search: 0.00354766845703125
# Time required for Binary Search: 0.00032329559326171875
# Time required for Learned Index: 0.022758960723876953
